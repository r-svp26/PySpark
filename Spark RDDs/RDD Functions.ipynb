# %%
from pyspark import SparkConf, SparkContext
conf = SparkConf().setAppName('Functions')
sc = SparkContext.getOrCreate(conf=conf)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd = sc.textFile('/FileStore/tables/Word_Count_Quiz.txt')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: 5</div>

# %%
rdd.flatMap(lambda x : x.split(' ')).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 22</div>

# %% [markdown]
# CountByValue()

# %%
rdd.countByValue()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: defaultdict(int,
#             {&#39;this mango company&#39;: 1,
#              &#39;cat mango ant animal laptop&#39;: 1,
#              &#39;chair switch mango am charger cover&#39;: 1,
#              &#39;animal any mango ant laptop laptop &#39;: 1,
#              &#39;this&#39;: 1})</div>

# %%
# Count times words are presents
rdd.flatMap(lambda x : x.split(' ')).countByValue()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: defaultdict(int,
#             {&#39;this&#39;: 2,
#              &#39;mango&#39;: 4,
#              &#39;company&#39;: 1,
#              &#39;cat&#39;: 1,
#              &#39;ant&#39;: 2,
#              &#39;animal&#39;: 2,
#              &#39;laptop&#39;: 3,
#              &#39;chair&#39;: 1,
#              &#39;switch&#39;: 1,
#              &#39;am&#39;: 1,
#              &#39;charger&#39;: 1,
#              &#39;cover&#39;: 1,
#              &#39;any&#39;: 1,
#              &#39;&#39;: 1})</div>
