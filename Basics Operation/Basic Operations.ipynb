# %%
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession.builder.appName("Ops").getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.read.csv('/FileStore/tables/appl_stock.csv',inferSchema=True,header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Date: string (nullable = true)
# -- Open: double (nullable = true)
# -- High: double (nullable = true)
# -- Low: double (nullable = true)
# -- Close: double (nullable = true)
# -- Volume: integer (nullable = true)
# -- Adj Close: double (nullable = true)
#
# </div>

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+------------------+------------------+------------------+------------------+---------+------------------+
#       Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# 2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# 2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# 2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# 2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# 2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|
# 2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|
# 2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|
# 2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|
# 2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|
# 2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|
# 2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|
# 2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|
# 2010-01-21|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|
# 2010-01-22|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|
# 2010-01-25|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|
# 2010-01-26|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|
# 2010-01-27|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|
# 2010-01-28|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|
# 2010-01-29|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|
# 2010-02-01|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows
#
# </div>

# %%
df.head(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [Row(Date=&#39;2010-01-04&#39;, Open=213.429998, High=214.499996, Low=212.38000099999996, Close=214.009998, Volume=123432400, Adj Close=27.727039),
#  Row(Date=&#39;2010-01-05&#39;, Open=214.599998, High=215.589994, Low=213.249994, Close=214.379993, Volume=150476200, Adj Close=27.774976000000002)]</div>

# %%
df.head(2)[0]
# Grab the first value
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: Row(Date=&#39;2010-01-04&#39;, Open=213.429998, High=214.499996, Low=212.38000099999996, Close=214.009998, Volume=123432400, Adj Close=27.727039)</div>

# %%
df.head(2)[1]
# Grab the second value
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: Row(Date=&#39;2010-01-05&#39;, Open=214.599998, High=215.589994, Low=213.249994, Close=214.379993, Volume=150476200, Adj Close=27.774976000000002)</div>

# %%
# Show all the results whos values are less than 500 using sql.
df.filter('Close < 500').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+------------------+------------------+------------------+------------------+---------+------------------+
#       Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# 2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# 2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# 2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# 2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# 2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|
# 2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|
# 2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|
# 2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|
# 2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|
# 2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|
# 2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|
# 2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|
# 2010-01-21|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|
# 2010-01-22|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|
# 2010-01-25|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|
# 2010-01-26|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|
# 2010-01-27|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|
# 2010-01-28|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|
# 2010-01-29|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|
# 2010-02-01|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows
#
# </div>

# %%
# Show spefic column value only
df.filter('Close < 500').select('Open').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#               Open|
# +------------------+
#         213.429998|
#         214.599998|
#         214.379993|
#             211.75|
#         210.299994|
# 212.79999700000002|
# 209.18999499999998|
#         207.870005|
# 210.11000299999998|
# 210.92999500000002|
#         208.330002|
#         214.910006|
#         212.079994|
# 206.78000600000001|
# 202.51000200000001|
# 205.95000100000001|
#         206.849995|
#         204.930004|
#         201.079996|
# 192.36999699999998|
# +------------------+
# only showing top 20 rows
#
# </div>

# %%
# Show multiple column value only
df.filter('Close < 500').select('Open','Close').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+------------------+
#               Open|             Close|
# +------------------+------------------+
#         213.429998|        214.009998|
#         214.599998|        214.379993|
#         214.379993|        210.969995|
#             211.75|            210.58|
#         210.299994|211.98000499999998|
# 212.79999700000002|210.11000299999998|
# 209.18999499999998|        207.720001|
#         207.870005|        210.650002|
# 210.11000299999998|            209.43|
# 210.92999500000002|            205.93|
#         208.330002|        215.039995|
#         214.910006|            211.73|
#         212.079994|        208.069996|
# 206.78000600000001|            197.75|
# 202.51000200000001|        203.070002|
# 205.95000100000001|        205.940001|
#         206.849995|        207.880005|
#         204.930004|        199.289995|
#         201.079996|        192.060003|
# 192.36999699999998|        194.729998|
# +------------------+------------------+
# only showing top 20 rows
#
# </div>

# %%
# Show multiple column value using normal python operator 
'''
    Using SQL
    df.filter('Close < 500').select('Open','Close').show()
'''
df.filter(df['Close'] < 500).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+------------------+------------------+------------------+------------------+---------+------------------+
#       Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# 2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# 2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# 2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# 2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# 2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|
# 2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|
# 2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|
# 2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|
# 2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|
# 2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|
# 2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|
# 2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|
# 2010-01-21|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|
# 2010-01-22|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|
# 2010-01-25|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|
# 2010-01-26|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|
# 2010-01-27|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|
# 2010-01-28|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|
# 2010-01-29|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|
# 2010-02-01|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows
#
# </div>

# %%
df.filter(df['Close'] < 500).select('Volume').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+
#    Volume|
# +---------+
# 123432400|
# 150476200|
# 138040000|
# 119282800|
# 111902700|
# 115557400|
# 148614900|
# 151473000|
# 108223500|
# 148516900|
# 182501900|
# 153038200|
# 152038600|
# 220441900|
# 266424900|
# 466777500|
# 430642100|
# 293375600|
# 311488100|
# 187469100|
# +---------+
# only showing top 20 rows
#
# </div>

# %%
# Filtering based multiple operation
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.filter( (df['Close'] < 500) & (df['Open'] > 200) ).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+------------------+------------------+------------------+------------------+---------+------------------+
#       Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# 2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# 2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# 2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# 2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# 2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|
# 2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|
# 2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|
# 2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|
# 2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|
# 2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|
# 2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|
# 2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|
# 2010-01-21|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|
# 2010-01-22|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|
# 2010-01-25|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|
# 2010-01-26|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|
# 2010-01-27|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|
# 2010-01-28|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|
# 2010-01-29|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|
# 2010-02-16|        201.940002|        203.690002|        201.520006|        203.399996|135934400|         26.352412|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows
#
# </div>

# %%
df.filter( (df['Close'] < 500) & ~(df['Open'] > 200) ).show()
'''
    & is for and
    | is for or
    ~ is for not
'''
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+------------------+------------------+------------------+------------------+---------+------------------+
#       Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# 2010-02-01|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|
# 2010-02-02|        195.909998|        196.319994|193.37999299999998|        195.859997|174585600|25.375532999999997|
# 2010-02-03|        195.169994|        200.200003|        194.420004|        199.229994|153832000|25.812148999999998|
# 2010-02-04|        196.730003|        198.370001|        191.570005|        192.050003|189413000|         24.881912|
# 2010-02-05|192.63000300000002|             196.0|        190.850002|        195.460001|212576700|25.323710000000002|
# 2010-02-08|        195.690006|197.88000300000002|        193.999994|194.11999699999998|119567700|           25.1501|
# 2010-02-09|        196.419996|        197.499994|        194.749998|196.19000400000002|158221700|         25.418289|
# 2010-02-10|        195.889997|             196.6|            194.26|195.12000700000002| 92590400|          25.27966|
# 2010-02-11|        194.880001|        199.750006|194.05999599999998|        198.669994|137586400|         25.739595|
# 2010-02-12|        198.109995|        201.639996|        195.500002|200.37999299999998|163867200|25.961142000000002|
# 2010-02-23|        199.999998|        201.330002|        195.709993|        197.059998|143773700|         25.531005|
# 2010-02-24|        198.229998|201.44000400000002|        197.840002|            200.66|115141600|         25.997419|
# 2010-02-25|        197.380005|        202.859997|        196.889994|        202.000004|166281500|          26.17103|
# 2014-06-09|         92.699997|         93.879997|             91.75|         93.699997| 75415000|         88.906324|
# 2014-06-10|         94.730003|         95.050003|             93.57|             94.25| 62777000|         89.428189|
# 2014-06-11|         94.129997|         94.760002|         93.470001|         93.860001| 45681000|         89.058142|
# 2014-06-12|         94.040001|         94.120003|         91.900002|         92.290001| 54749000|         87.568463|
# 2014-06-13|         92.199997|         92.440002|         90.879997|         91.279999| 54525000|         86.610132|
# 2014-06-16|         91.510002|             92.75|         91.449997|         92.199997| 35561000|         87.483064|
# 2014-06-17|         92.309998|         92.699997|         91.800003| 92.08000200000001| 29726000| 87.36920699999999|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows
#
# Out[28]: &#39;\n    &amp; is for and\n    | is for or\n    ~ is for not\n&#39;</div>

# %%
df.filter( (df['Open'] <= 500) & (df['Close'] > 200) ).show()
'''
    & is for and
    | is for or
    ~ is for not
'''
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+------------------+------------------+------------------+------------------+---------+------------------+
#       Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# 2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# 2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# 2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# 2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# 2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|
# 2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|
# 2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|
# 2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|
# 2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|
# 2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|
# 2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|
# 2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|
# 2010-01-21|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|
# 2010-01-25|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|
# 2010-01-26|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|
# 2010-01-27|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|
# 2010-02-12|        198.109995|        201.639996|        195.500002|200.37999299999998|163867200|25.961142000000002|
# 2010-02-16|        201.940002|        203.690002|        201.520006|        203.399996|135934400|         26.352412|
# 2010-02-17|        204.190001|        204.310003|        200.860004|        202.550003|109099200|         26.242287|
# 2010-02-18|        201.629995|        203.889994|        200.920006|        202.929998|105706300|         26.291519|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows
#
# Out[30]: &#39;\n    &amp; is for and\n    | is for or\n    ~ is for not\n&#39;</div>

# %%
# Collect method
result = df.filter(df['Low'] == 197.16).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: [Row(Date=&#39;2010-01-22&#39;, Open=206.78000600000001, High=207.499996, Low=197.16, Close=197.75, Volume=220441900, Adj Close=25.620401)]</div>

# %%
row = result[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# As a dictionary
row.asDict()['Volume']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: 220441900</div>
